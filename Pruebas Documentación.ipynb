# %%
import pandas as pd
import requests
import sqlite3
import time
# Out:
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
def get_bitso_trades():
    """
    This function gets the publicly available bitso trades and returns them in a DataFrame.
    :return: pd.DataFrame with the bitso trades.
    """
    # Get request
    response = requests.get("https://api.bitso.com/v3/trades/?book=btc_mxn")
    data = response.json().get("payload")

    # To data frame
    df = pd.DataFrame(data)
    return df

# %%
r=get_bitso_trades()
r.head()
# Out:
#       book                created_at      amount maker_side      price  \
# 0  btc_mxn  2021-09-30T03:16:55+0000  0.00039508        buy  885011.61
# 1  btc_mxn  2021-09-30T03:16:55+0000  0.00117429        buy  885289.54
# 2  btc_mxn  2021-09-30T03:16:55+0000  0.00193063        buy  885509.60
# 3  btc_mxn  2021-09-30T03:16:47+0000  0.00010824        buy  885713.15
# 4  btc_mxn  2021-09-30T03:16:39+0000  0.00100000        buy  885289.54
#
#         tid
# 0  46928622
# 1  46928621
# 2  46928619
# 3  46928617
# 4  46928614

# %%
import ccxt

hitbtc   = ccxt.hitbtc({'verbose': True})
bitmex   = ccxt.bitmex()
huobipro = ccxt.huobipro()
exmo     = ccxt.exmo({
    'apiKey': 'YOUR_PUBLIC_API_KEY',
    'secret': 'YOUR_SECRET_PRIVATE_KEY',
})
kraken = ccxt.kraken({
    'apiKey': 'YOUR_PUBLIC_API_KEY',
    'secret': 'YOUR_SECRET_PRIVATE_KEY',
})

exchange_id = 'binance'
exchange_class = getattr(ccxt, exchange_id)
exchange = exchange_class({
    'apiKey': 'YOUR_API_KEY',
    'secret': 'YOUR_SECRET',
})

hitbtc_markets = hitbtc.load_markets()

print(hitbtc.id, hitbtc_markets)
print(bitmex.id, bitmex.load_markets())
print(huobipro.id, huobipro.load_markets())

print(hitbtc.fetch_order_book(hitbtc.symbols[0]))
print(bitmex.fetch_ticker('BTC/USD'))
print(huobipro.fetch_trades('LTC/USDT'))

print(exmo.fetch_balance())

# sell one ฿ for market price and receive $ right now
print(exmo.id, exmo.create_market_sell_order('BTC/USD', 1))

# limit buy BTC/EUR, you pay €2500 and receive ฿1  when the order is closed
print(exmo.id, exmo.create_limit_buy_order('BTC/EUR', 1, 2500.00))

# pass/redefine custom exchange-specific order params: type, amount, price, flags, etc...
kraken.create_market_buy_order('BTC/USD', 1, {'trading_agreement': 'agree'})
exmo
# Out:
# Request: GET https://api.hitbtc.com/api/2/public/currency {'User-Agent': 'python-requests/2.22.0', 'Accept-Encoding': 'gzip, deflate'} None
#
# Response: GET https://api.hitbtc.com/api/2/public/currency 200 {'Server': 'nginx', 'Date': 'Thu, 30 Sep 2021 03:17:22 GMT', 'Content-Type': 'application/json', 'Content-Length': '25113', 'Connection': 'keep-alive', 'content-encoding': 'gzip', 'Request-ID': '350da4e603ca4782c7d2370e4b200964', 'Referrer-Policy': 'strict-origin-when-cross-origin'} [{"id":"MTL","fullName":"Metal","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"8.711000000000","precisionPayout":18,"precisionTransfer":8},{"id":"IQ","fullName":"IQ.cash","crypto":true,"payinEnabled":false,"payinPaymentId":false,"payinConfirmations":6,"payoutEnabled":false,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"23.000000000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"40.407","highProcessingTime":"1976.197","avgProcessingTime":"1936.691081632653"},{"id":"TTU","fullName":"TTU","crypto":true,"payinEnabled":false,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"505.700000000000","precisionPayout":8,"precisionTransfer":8},{"id":"BNT","fullName":"Bancor Network","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"6.984000000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"533.388","highProcessingTime":"1838.305","avgProcessingTime":"1172.5310204081632"},{"id":"ICN","fullName":"ICN","crypto":true,"payinEnabled":false,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":false,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"82.000000000000","precisionPayout":18,"precisionTransfer":8},{"id":"INJ","fullName":"Injective Protocol","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"2.564400000000","precisionPayout":8,"precisionTransfer":8},{"id":"CELO","fullName":"Celo","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":720,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"0.750020000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"899.021","highProcessingTime":"17639.549","avgProcessingTime":"9015.640636363638"},{"id":"NGC","fullName":"NAGA Coin","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"369.300000000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"2.17","highProcessingTime":"5431.161","avgProcessingTime":"781.5765999999998"},{"id":"BZRX","fullName":"bZx Protocol","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"84.900000000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"3205.391","highProcessingTime":"3205.391","avgProcessingTime":"3205.391000000002"},{"id":"TRST","fullName":"WeTrust","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"3660.000000000000","precisionPayout":6,"precisionTransfer":6},{"id":"UBT","fullName":"Unibright","crypto":true,"payinEnabled":true,"payinPaymentId":false,"payinConfirmations":9,"payoutEnabled":true,"payoutIsPaymentId":false,"transferEnabled":true,"delisted":false,"payoutFee":"9.210000000000","precisionPayout":8,"precisionTransfer":8,"lowProcessingTime":"2.234","highProcessingTime":"291.248","avgProcessingTime":"143.7918775510204"},{"id":"ATRI","ful ...
# Request: GET https://api.hitbtc.com/api/2/public/symbol {'User-Agent': 'python-requests/2.22.0', 'Accept-Encoding': 'gzip, deflate'} None
#
# Response: GET https://api.hitbtc.com/api/2/public/symbol 200 {'Server': 'nginx', 'Date': 'Thu, 30 Sep 2021 03:17:23 GMT', 'Content-Type': 'application/json', 'Content-Length': '14786', 'Connection': 'keep-alive', 'content-encoding': 'gzip', 'Request-ID': '9ed7e97988802ea28b0fc46c1a8d3e87', 'Referrer-Policy': 'strict-origin-when-cross-origin'} [{"id":"LINKHIT","baseCurrency":"LINK","quoteCurrency":"HIT","quantityIncrement":"0.001","tickSize":"0.01","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"HIT"},{"id":"GRTBTC","baseCurrency":"GRT","quoteCurrency":"BTC","quantityIncrement":"0.01","tickSize":"0.000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"RAISEETH","baseCurrency":"RAISE","quoteCurrency":"ETH","quantityIncrement":"1","tickSize":"0.000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"ETH"},{"id":"NAVBTC","baseCurrency":"NAV","quoteCurrency":"BTC","quantityIncrement":"1","tickSize":"0.000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"XDCETH","baseCurrency":"XDC","quoteCurrency":"ETH","quantityIncrement":"0.1","tickSize":"0.00000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"ETH"},{"id":"VETHIT","baseCurrency":"VET","quoteCurrency":"HIT","quantityIncrement":"1","tickSize":"0.0001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"HIT"},{"id":"SNXETH","baseCurrency":"SNX","quoteCurrency":"ETH","quantityIncrement":"0.01","tickSize":"0.0000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"ETH"},{"id":"HOTBTC","baseCurrency":"HOT","quoteCurrency":"BTC","quantityIncrement":"100","tickSize":"0.00000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"DAVBTC","baseCurrency":"DAV","quoteCurrency":"BTC","quantityIncrement":"10","tickSize":"0.00000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"TXAUSDC","baseCurrency":"TXA","quoteCurrency":"USDC","quantityIncrement":"0.01","tickSize":"0.00001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"USDC"},{"id":"ETHUSDP","baseCurrency":"ETH","quoteCurrency":"USDP","quantityIncrement":"0.0001","tickSize":"0.001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"USDP"},{"id":"ARPAUSD","baseCurrency":"ARPA","quoteCurrency":"USD","quantityIncrement":"10","tickSize":"0.00000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"USD"},{"id":"AEONBTC","baseCurrency":"AEON","quoteCurrency":"BTC","quantityIncrement":"0.1","tickSize":"0.000000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"ETCBTC","baseCurrency":"ETC","quoteCurrency":"BTC","quantityIncrement":"0.01","tickSize":"0.0000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC","marginTrading":true,"maxInitialLeverage":"3.00"},{"id":"IDEXUSDT","baseCurrency":"IDEX","quoteCurrency":"USD","quantityIncrement":"0.1","tickSize":"0.000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"USD"},{"id":"IOTAETH","baseCurrency":"IOTA","quoteCurrency":"ETH","quantityIncrement":"0.1","tickSize":"0.00000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"ETH","marginTrading":true,"maxInitialLeverage":"5.00"},{"id":"BDPUSD","baseCurrency":"BDP","quoteCurrency":"USD","quantityIncrement":"1","tickSize":"0.0000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"USD"},{"id":"PERPBTC","baseCurrency":"PERP","quoteCurrency":"BTC","quantityIncrement":"0.01","tickSize":"0.00000001","takeLiquidityRate":"0.0025","provideLiquidityRate":"0.001","feeCurrency":"BTC"},{"id":"XVGBTC","baseCurrency":"XVG","quoteCurrency":"BTC","quantityIncrement":"10","tickSize":"0.0000000001","takeLiquidityRate":"0.0025","provi ...
# hitbtc {'LINK/HIT': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 0.01, 'amount': 0.001}, 'limits': {'amount': {'min': 0.001, 'max': None}, 'price': {'min': 0.01, 'max': None}, 'cost': {'min': 1e-05, 'max': None}}, 'info': {'id': 'LINKHIT', 'baseCurrency': 'LINK', 'quoteCurrency': 'HIT', 'quantityIncrement': '0.001', 'tickSize': '0.01', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'HIT'}, 'id': 'LINKHIT', 'symbol': 'LINK/HIT', 'base': 'LINK', 'quote': 'HIT', 'baseId': 'LINK', 'quoteId': 'HIT', 'active': True, 'feeCurrency': 'HIT'}, 'GRT/BTC': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 1e-09, 'amount': 0.01}, 'limits': {'amount': {'min': 0.01, 'max': None}, 'price': {'min': 1e-09, 'max': None}, 'cost': {'min': 1e-11, 'max': None}}, 'info': {'id': 'GRTBTC', 'baseCurrency': 'GRT', 'quoteCurrency': 'BTC', 'quantityIncrement': '0.01', 'tickSize': '0.000000001', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'BTC'}, 'id': 'GRTBTC', 'symbol': 'GRT/BTC', 'base': 'GRT', 'quote': 'BTC', 'baseId': 'GRT', 'quoteId': 'BTC', 'active': True, 'feeCurrency': 'BTC'}, 'RAISE/ETH': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 1e-09, 'amount': 1.0}, 'limits': {'amount': {'min': 1.0, 'max': None}, 'price': {'min': 1e-09, 'max': None}, 'cost': {'min': 1e-09, 'max': None}}, 'info': {'id': 'RAISEETH', 'baseCurrency': 'RAISE', 'quoteCurrency': 'ETH', 'quantityIncrement': '1', 'tickSize': '0.000000001', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'ETH'}, 'id': 'RAISEETH', 'symbol': 'RAISE/ETH', 'base': 'RAISE', 'quote': 'ETH', 'baseId': 'RAISE', 'quoteId': 'ETH', 'active': True, 'feeCurrency': 'ETH'}, 'NAV/BTC': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 1e-09, 'amount': 1.0}, 'limits': {'amount': {'min': 1.0, 'max': None}, 'price': {'min': 1e-09, 'max': None}, 'cost': {'min': 1e-09, 'max': None}}, 'info': {'id': 'NAVBTC', 'baseCurrency': 'NAV', 'quoteCurrency': 'BTC', 'quantityIncrement': '1', 'tickSize': '0.000000001', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'BTC'}, 'id': 'NAVBTC', 'symbol': 'NAV/BTC', 'base': 'NAV', 'quote': 'BTC', 'baseId': 'NAV', 'quoteId': 'BTC', 'active': True, 'feeCurrency': 'BTC'}, 'XDC/ETH': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 1e-08, 'amount': 0.1}, 'limits': {'amount': {'min': 0.1, 'max': None}, 'price': {'min': 1e-08, 'max': None}, 'cost': {'min': 1e-09, 'max': None}}, 'info': {'id': 'XDCETH', 'baseCurrency': 'XDC', 'quoteCurrency': 'ETH', 'quantityIncrement': '0.1', 'tickSize': '0.00000001', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'ETH'}, 'id': 'XDCETH', 'symbol': 'XDC/ETH', 'base': 'XDC', 'quote': 'ETH', 'baseId': 'XDC', 'quoteId': 'ETH', 'active': True, 'feeCurrency': 'ETH'}, 'VET/HIT': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 0.0001, 'amount': 1.0}, 'limits': {'amount': {'min': 1.0, 'max': None}, 'price': {'min': 0.0001, 'max': None}, 'cost': {'min': 0.0001, 'max': None}}, 'info': {'id': 'VETHIT', 'baseCurrency': 'VET', 'quoteCurrency': 'HIT', 'quantityIncrement': '1', 'tickSize': '0.0001', 'takeLiquidityRate': '0.0025', 'provideLiquidityRate': '0.001', 'feeCurrency': 'HIT'}, 'id': 'VETHIT', 'symbol': 'VET/HIT', 'base': 'VET', 'quote': 'HIT', 'baseId': 'VET', 'quoteId': 'HIT', 'active': True, 'feeCurrency': 'HIT'}, 'SNX/ETH': {'percentage': True, 'tierBased': False, 'maker': 0.001, 'taker': 0.0025, 'precision': {'price': 1e-07, 'amount': 0.01}, 'limits': {'amount': {'min': 0.01, 'max': None}, 'price': {'min': 1e-07, 'max': None}, 'cost': {'min': 1e-09, 'max': None}}, 'info': {'id': 'SNXETH', 'baseCurrency': 'SNX', 'quoteCur ...
# bitmex {'.EVOL7D': {'percentage': True, 'precision': {'amount': None, 'price': 0.01}, 'limits': {'amount': {'min': None, 'max': None}, 'price': {'min': 0.01, 'max': None}, 'cost': {'min': None, 'max': None}}, 'id': '.EVOL7D', 'symbol': '.EVOL7D', 'base': 'ETH', 'quote': 'XXX', 'baseId': 'ETH', 'quoteId': 'XXX', 'active': False, 'taker': None, 'maker': None, 'type': 'future', 'spot': False, 'swap': False, 'future': True, 'prediction': False, 'info': {'symbol': '.EVOL7D', 'rootSymbol': 'EVOL', 'state': 'Unlisted', 'typ': 'MRIXXX', 'listing': None, 'front': None, 'expiry': None, 'settle': None, 'listedSettle': None, 'relistInterval': None, 'inverseLeg': '', 'sellLeg': '', 'buyLeg': '', 'optionStrikePcnt': None, 'optionStrikeRound': None, 'optionStrikePrice': None, 'optionMultiplier': None, 'positionCurrency': '', 'underlying': 'ETH', 'quoteCurrency': 'XXX', 'underlyingSymbol': '.EVOL7D', 'reference': 'BMEX', 'referenceSymbol': '.BETHXBT', 'calcInterval': '2000-01-08T00:00:00.000Z', 'publishInterval': '2000-01-01T00:05:00.000Z', 'publishTime': None, 'maxOrderQty': None, 'maxPrice': None, 'lotSize': None, 'tickSize': '0.01', 'multiplier': None, 'settlCurrency': '', 'underlyingToPositionMultiplier': None, 'underlyingToSettleMultiplier': None, 'quoteToSettleMultiplier': None, 'isQuanto': False, 'isInverse': False, 'initMargin': None, 'maintMargin': None, 'riskLimit': None, 'riskStep': None, 'limit': None, 'capped': False, 'taxed': False, 'deleverage': False, 'makerFee': None, 'takerFee': None, 'settlementFee': None, 'insuranceFee': None, 'fundingBaseSymbol': '', 'fundingQuoteSymbol': '', 'fundingPremiumSymbol': '', 'fundingTimestamp': None, 'fundingInterval': None, 'fundingRate': None, 'indicativeFundingRate': None, 'rebalanceTimestamp': None, 'rebalanceInterval': None, 'openingTimestamp': None, 'closingTimestamp': None, 'sessionInterval': None, 'prevClosePrice': None, 'limitDownPrice': None, 'limitUpPrice': None, 'bankruptLimitDownPrice': None, 'bankruptLimitUpPrice': None, 'prevTotalVolume': None, 'totalVolume': None, 'volume': None, 'volume24h': None, 'prevTotalTurnover': None, 'totalTurnover': None, 'turnover': None, 'turnover24h': None, 'homeNotional24h': None, 'foreignNotional24h': None, 'prevPrice24h': '6.81', 'vwap': None, 'highPrice': None, 'lowPrice': None, 'lastPrice': '6.68', 'lastPriceProtected': None, 'lastTickDirection': 'ZeroPlusTick', 'lastChangePcnt': '-0.0191', 'bidPrice': None, 'midPrice': None, 'askPrice': None, 'impactBidPrice': None, 'impactMidPrice': None, 'impactAskPrice': None, 'hasLiquidity': False, 'openInterest': None, 'openValue': '0', 'fairMethod': '', 'fairBasisRate': None, 'fairBasis': None, 'fairPrice': None, 'markMethod': 'LastPrice', 'markPrice': '6.68', 'indicativeTaxRate': None, 'indicativeSettlePrice': None, 'optionUnderlyingPrice': None, 'settledPriceAdjustmentRate': None, 'settledPrice': None, 'timestamp': '2021-09-30T02:55:00.000Z'}}, '.BADAXBT': {'percentage': True, 'precision': {'amount': None, 'price': 1e-08}, 'limits': {'amount': {'min': None, 'max': None}, 'price': {'min': 1e-08, 'max': None}, 'cost': {'min': None, 'max': None}}, 'id': '.BADAXBT', 'symbol': '.BADAXBT', 'base': 'ADA', 'quote': 'BTC', 'baseId': 'ADA', 'quoteId': 'XBT', 'active': False, 'taker': None, 'maker': None, 'type': 'future', 'spot': False, 'swap': False, 'future': True, 'prediction': False, 'info': {'symbol': '.BADAXBT', 'rootSymbol': 'ADA', 'state': 'Unlisted', 'typ': 'MRCXXX', 'listing': None, 'front': None, 'expiry': None, 'settle': None, 'listedSettle': None, 'relistInterval': None, 'inverseLeg': '', 'sellLeg': '', 'buyLeg': '', 'optionStrikePcnt': None, 'optionStrikeRound': None, 'optionStrikePrice': None, 'optionMultiplier': None, 'positionCurrency': '', 'underlying': 'ADA', 'quoteCurrency': 'XBT', 'underlyingSymbol': 'ADAXBT=', 'reference': 'BMI', 'referenceSymbol': '.BADAXBT', 'calcInterval': None, 'publishInterval': '2000-01-01T00:01:00.000Z', 'publishTime': None, 'maxOrderQty': None, 'maxPrice': None, 'lo ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  GET https://api.hitbtc.com/api/2/public/orderbook/1INCHBTC 200 {'Server': 'nginx', 'Date': 'Thu, 30 Sep 2021 03:17:25 GMT', 'Content-Type': 'application/json', 'Content-Length': '1612', 'Connection': 'keep-alive', 'content-encoding': 'gzip', 'Request-ID': '6fffbd3111e1dc86183d8137a051e8b6', 'Referrer-Policy': 'strict-origin-when-cross-origin'} {"symbol":"1INCHBTC","timestamp":"2021-09-30T03:17:24.749Z","batchingTime":"2021-09-30T03:17:24.840Z","ask":[{"price":"0.000059820","size":"157.7"},{"price":"0.000059825","size":"152.7"},{"price":"0.000059843","size":"169.8"},{"price":"0.000059873","size":"657.9"},{"price":"0.000059877","size":"691.2"},{"price":"0.000059947","size":"2244.8"},{"price":"0.000059955","size":"162.6"},{"price":"0.000059967","size":"1551.2"},{"price":"0.000059972","size":"1767.5"},{"price":"0.000060015","size":"3077.2"},{"price":"0.000060022","size":"2450.9"},{"price":"0.000060023","size":"661.7"},{"price":"0.000060100","size":"2373.4"},{"price":"0.000060119","size":"11170.0"},{"price":"0.000060128","size":"1836.6"},{"price":"0.000060136","size":"3456.3"},{"price":"0.000060209","size":"2394.1"},{"price":"0.000060249","size":"3207.6"},{"price":"0.000060264","size":"10995.4"},{"price":"0.000060287","size":"4245.8"},{"price":"0.000060314","size":"3634.0"},{"price":"0.000060345","size":"3968.6"},{"price":"0.000060361","size":"10473.5"},{"price":"0.000060407","size":"6326.0"},{"price":"0.000060414","size":"10459.0"},{"price
Multiplier': None, 'underlyingToSettleMultiplier': '-100000000', 'quoteToSettleMultiplier': None, 'isQuanto': False, 'isInverse': True, 'initMargin': '0.01', 'maintMargin': '0.0035', 'riskLimit': '20000000000', 'riskStep': '15000000000', 'limit': None, 'capped': False, 'taxed': True, 'deleverage': True, 'makerFee': '-0.0001', 'takerFee': '0.0005', 'settlementFee': '0', 'insuranceFee': '0', 'fundingBaseSymbol': '.XBTBON8H', 'fundingQuoteSymbol': '.USDBON8H', 'fundingPremiumSymbol': '.XBTUSDPI8H', 'fundingTimestamp': '2021-09-30T04:00:00.000Z', 'fundingInterval': '2000-01-01T08:00:00.000Z', 'fundingRate': '0.000011', 'indicativeFundingRate': '-0.000162', 'rebalanceTimestamp': None, 'rebalanceInterval': None, 'openingTimestamp': '2021-09-30T03:00:00.000Z', 'closingTimestamp': '2021-09-30T04:00:00.000Z', 'sessionInterval': '2000-01-01T01:00:00.000Z', 'prevClosePrice': '42404.45', 'limitDownPrice': None, 'limitUpPrice': None, 'bankruptLimitDownPrice': None, 'bankruptLimitUpPrice': None, 'prevTotalVolume': '3265975291589', 'totalVolume': '3265994106189', 'volume': '18814600', 'volume24h': '1220128900', 'prevTotalTurnover': '35976556633757736', 'totalTurnover': '35976600035323570', 'turnover': '43401565833', 'turnover24h': '2901675890037', 'homeNotional24h': '29016.75890036995', 'foreignNotional24h': '1220128900', 'prevPrice24h': '41740', 'vwap': '42049.1386', 'highPrice': '43472', 'lowPrice': '40866', 'lastPrice': '43288.5', 'lastPriceProtected': '43288.5', 'lastTickDirection': 'ZeroPlusTick', 'lastChangePcnt': '0.0371', 'bidPrice': '43288', 'midPrice': '43288.25', 'askPrice': '43288.5', 'impactBidPrice': '43287.982', 'impactMidPrice': '43288.25', 'impactAskPrice': '43288.5441', 'hasLiquidity': True, 'openInterest': '643091600', 'openValue': '1485091431880', 'fairMethod': 'FundingRate', 'fairBasisRate': '0.012045', 'fairBasis': '0.04', 'fairPrice': '43303.09', 'markMethod': 'FairPrice', 'markPrice': '43303.09', 'indicativeTaxRate': '0', 'indicativeSettlePrice': '43303.05', 'optionUnderlyingPrice': None, 'settledPriceAdjustmentRate': None, 'settledPrice': None, 'timestamp': '2021-09-30T03:17:20.000Z'}}
# [{'id': '110765415069375970670517232', 'info': {'id': '110765415069375970670517232', 'ts': '1632970797003', 'trade-id': '101524764696', 'amount': '0.0664', 'price': '150.34', 'direction': 'sell'}, 'order': None, 'timestamp': 1632970797003, 'datetime': '2021-09-30T02:59:57.003Z', 'symbol': 'LTC/USDT', 'type': None, 'side': 'sell', 'takerOrMaker': None, 'price': 150.34, 'amount': 0.0664, 'cost': 9.982576, 'fee': None}, {'id': '110765415269375970679628182', 'info': {'id': '110765415269375970679628182', 'ts': '1632970797461', 'trade-id': '101524764697', 'amount': '0.4444', 'price': '150.41', 'direction': 'sell'}, 'order': None, 'timestamp': 1632970797461, 'datetime': '2021-09-30T02:59:57.461Z', 'symbol': 'LTC/USDT', 'type': None, 'side': 'sell', 'takerOrMaker': None, 'price': 150
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-4-dd54db24eec0> in <module>()
#      31 print(huobipro.fetch_trades('LTC/USDT'))
#      32
# ---> 33 print(exmo.fetch_balance())
#      34
#      35 # sell one ฿ for market price and receive $ right now
#
# ~\Anaconda3\lib\site-packages\ccxt\exmo.py in fetch_balance(self, params)
#     527     def fetch_balance(self, params={}):
#     528         self.load_markets()
# --> 529         response = self.privatePostUserInfo(params)
#     530         #
#     531         #     {
#
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in inner(_self, params, context)
#     455                 if context is not None:
#     456                     inner_kwargs['context'] = params
# --> 457                 return entry(_self, **inner_kwargs)
#     458             return inner
#     459         to_bind = partialer()
#
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in request(self, path, api, method, params, headers, body, config, context)
#     504     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}, context={}):
#     505         """Exchange.request is the entry point for all generated methods"""
# --> 506         return self.fetch2(path, api, method, params, headers, body, config, context)
#     507
#     508     @staticmethod
#
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch2(self, path, api, method, params, headers, body, config, context)
#     500         self.lastRestRequestTimestamp = self.milliseconds()
#     501         request = self.sign(path, api, method, params, headers, body)
# --> 502         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     503
#     504     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}, context={}):
#
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     652                 raise ExchangeError(details) from e
#     653
# --> 654         self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     655         if json_response is not None:
#     656             return json_response
#
# ~\Anaconda3\lib\site-packages\ccxt\exmo.py in handle_errors(self, httpCode, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    1376                     code = errorSubParts[1] if (numSubParts > 1) else errorSubParts[0]
#    1377                 feedback = self.id + ' ' + body
# -> 1378                 self.throw_exactly_matched_exception(self.exceptions['exact'], code, feedback)
#    1379                 self.throw_broadly_matched_exception(self.exceptions['broad'], message, feedback)
#    1380                 raise ExchangeError(feedback)
#
# ~\Anaconda3\lib\site-packages\ccxt\base\exchange.py in throw_exactly_matched_exception(self, exact, string, message)
#     518     def throw_exactly_matched_exception(self, exact, string, message):
#     519         if string in exact:
# --> 520             raise exact[string](message)
#     521
#     522     def throw_broadly_matched_exception(self, broad, string, message):
#
# AuthenticationError: exmo {"result":false,"error":"Error 40017: Wrong api key"}

# %%
exchange = ccxt.binance ({
    'rateLimit': 10000,  # unified exchange property
    'headers': {
        'YOUR_CUSTOM_HTTP_HEADER': 'YOUR_CUSTOM_VALUE',
    },
    'options': {
        'adjustForTimeDifference': True,  # exchange-specific option
    }
})
exchange.options['adjustForTimeDifference'] = False

# %%
r=pd.DataFrame(exchange.load_markets())
r
# Out:
#                                                           ETH/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 4, 'price': 6}
# limits          {'amount': {'min': 0.0001, 'max': 100000.0}, '...
# id                                                         ETHBTC
# lowercaseId                                                ethbtc
# symbol                                                    ETH/BTC
# base                                                          ETH
# quote                                                         BTC
# baseId                                                        ETH
# quoteId                                                       BTC
# info            {'symbol': 'ETHBTC', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                       True
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           LTC/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 3, 'price': 6}
# limits          {'amount': {'min': 0.001, 'max': 100000.0}, 'p...
# id                                                         LTCBTC
# lowercaseId                                                ltcbtc
# symbol                                                    LTC/BTC
# base                                                          LTC
# quote                                                         BTC
# baseId                                                        LTC
# quoteId                                                       BTC
# info            {'symbol': 'LTCBTC', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                       True
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           BNB/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 3, 'price': 6}
# limits          {'amount': {'min': 0.001, 'max': 100000.0}, 'p...
# id                                                         BNBBTC
# lowercaseId                                                bnbbtc
# symbol                                                    BNB/BTC
# base                                                          BNB
# quote                                                         BTC
# baseId                                                        BNB
# quoteId                                                       BTC
# info            {'symbol': 'BNBBTC', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                       True
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           NEO/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 2, 'price': 6}
# limits          {'amount': {'min': 0.01, 'max': 100000.0}, 'pr...
# id                                                         NEOBTC
# lowercaseId                                                neobtc
# symbol                                                    NEO/BTC
# base                                                          NEO
# quote                                                         BTC
# baseId                                                        NEO
# quoteId                                                       BTC
# info            {'symbol': 'NEOBTC', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                       True
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          QTUM/ETH  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 6}
# limits          {'amount': {'min': 0.1, 'max': 90000000.0}, 'p...
# id                                                        QTUMETH
# lowercaseId                                               qtumeth
# symbol                                                   QTUM/ETH
# base                                                         QTUM
# quote                                                         ETH
# baseId                                                       QTUM
# quoteId                                                       ETH
# info            {'symbol': 'QTUMETH', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           EOS/ETH  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 6}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                         EOSETH
# lowercaseId                                                eoseth
# symbol                                                    EOS/ETH
# base                                                          EOS
# quote                                                         ETH
# baseId                                                        EOS
# quoteId                                                       ETH
# info            {'symbol': 'EOSETH', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                       True
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           SNT/ETH  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 0, 'price': 8}
# limits          {'amount': {'min': 1.0, 'max': 90000000.0}, 'p...
# id                                                         SNTETH
# lowercaseId                                                snteth
# symbol                                                    SNT/ETH
# base                                                          SNT
# quote                                                         ETH
# baseId                                                        SNT
# quoteId                                                       ETH
# info            {'symbol': 'SNTETH', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           BNT/ETH  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 6}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                         BNTETH
# lowercaseId                                                bnteth
# symbol                                                    BNT/ETH
# base                                                          BNT
# quote                                                         ETH
# baseId                                                        BNT
# quoteId                                                       ETH
# info            {'symbol': 'BNTETH', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           BCC/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 3, 'price': 6}
# limits          {'amount': {'min': 0.001, 'max': 92141578.0}, ...
# id                                                         BCCBTC
# lowercaseId                                                bccbtc
# symbol                                                    BCC/BTC
# base                                                          BCC
# quote                                                         BTC
# baseId                                                        BCC
# quoteId                                                       BTC
# info            {'symbol': 'BCCBTC', 'status': 'BREAK', 'baseA...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                      False
# contractSize                                                 None
#
#                                                           GAS/BTC  ...  \
# percentage                                                   True  ...
# feeSide                                                       get  ...
# tierBased                                                   False  ...
# taker                                                       0.001  ...
# maker                                                       0.001  ...
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 7}  ...
# limits          {'amount': {'min': 0.1, 'max': 90000000.0}, 'p...  ...
# id                                                         GASBTC  ...
# lowercaseId                                                gasbtc  ...
# symbol                                                    GAS/BTC  ...
# base                                                          GAS  ...
# quote                                                         BTC  ...
# baseId                                                        GAS  ...
# quoteId                                                       BTC  ...
# info            {'symbol': 'GASBTC', 'status': 'TRADING', 'bas...  ...
# spot                                                         True  ...
# type                                                         spot  ...
# margin                                                      False  ...
# future                                                      False  ...
# delivery                                                    False  ...
# linear                                                      False  ...
# inverse                                                     False  ...
# expiry                                                       None  ...
# expiryDatetime                                               None  ...
# active                                                       True  ...
# contractSize                                                 None  ...
#
#                                                          YGG/BUSD  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 3}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                        YGGBUSD
# lowercaseId                                               yggbusd
# symbol                                                   YGG/BUSD
# base                                                          YGG
# quote                                                        BUSD
# baseId                                                        YGG
# quoteId                                                      BUSD
# info            {'symbol': 'YGGBUSD', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           YGG/BNB  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 5}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                         YGGBNB
# lowercaseId                                                yggbnb
# symbol                                                    YGG/BNB
# base                                                          YGG
# quote                                                         BNB
# baseId                                                        YGG
# quoteId                                                       BNB
# info            {'symbol': 'YGGBNB', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           YGG/BTC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 7}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                         YGGBTC
# lowercaseId                                                yggbtc
# symbol                                                    YGG/BTC
# base                                                          YGG
# quote                                                         BTC
# baseId                                                        YGG
# quoteId                                                       BTC
# info            {'symbol': 'YGGBTC', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          STX/BUSD  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 1, 'price': 3}
# limits          {'amount': {'min': 0.1, 'max': 92141578.0}, 'p...
# id                                                        STXBUSD
# lowercaseId                                               stxbusd
# symbol                                                   STX/BUSD
# base                                                          STX
# quote                                                        BUSD
# baseId                                                        STX
# quoteId                                                      BUSD
# info            {'symbol': 'STXBUSD', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          SYS/USDT  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 0, 'price': 4}
# limits          {'amount': {'min': 1.0, 'max': 92141578.0}, 'p...
# id                                                        SYSUSDT
# lowercaseId                                               sysusdt
# symbol                                                   SYS/USDT
# base                                                          SYS
# quote                                                        USDT
# baseId                                                        SYS
# quoteId                                                      USDT
# info            {'symbol': 'SYSUSDT', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           DF/USDT  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 0, 'price': 4}
# limits          {'amount': {'min': 1.0, 'max': 92141578.0}, 'p...
# id                                                         DFUSDT
# lowercaseId                                                dfusdt
# symbol                                                    DF/USDT
# base                                                           DF
# quote                                                        USDT
# baseId                                                         DF
# quoteId                                                      USDT
# info            {'symbol': 'DFUSDT', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          SOL/USDC  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 2, 'price': 2}
# limits          {'amount': {'min': 0.01, 'max': 922327.0}, 'pr...
# id                                                        SOLUSDC
# lowercaseId                                               solusdc
# symbol                                                   SOL/USDC
# base                                                          SOL
# quote                                                        USDC
# baseId                                                        SOL
# quoteId                                                      USDC
# info            {'symbol': 'SOLUSDC', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          ARPA/RUB  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 0, 'price': 3}
# limits          {'amount': {'min': 1.0, 'max': 92141578.0}, 'p...
# id                                                        ARPARUB
# lowercaseId                                               arparub
# symbol                                                   ARPA/RUB
# base                                                         ARPA
# quote                                                         RUB
# baseId                                                       ARPA
# quoteId                                                       RUB
# info            {'symbol': 'ARPARUB', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                           LTC/UAH  \
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 3, 'price': 0}
# limits          {'amount': {'min': 0.001, 'max': 92233.0}, 'pr...
# id                                                         LTCUAH
# lowercaseId                                                ltcuah
# symbol                                                    LTC/UAH
# base                                                          LTC
# quote                                                         UAH
# baseId                                                        LTC
# quoteId                                                       UAH
# info            {'symbol': 'LTCUAH', 'status': 'TRADING', 'bas...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
#                                                          FET/BUSD
# percentage                                                   True
# feeSide                                                       get
# tierBased                                                   False
# taker                                                       0.001
# maker                                                       0.001
# precision        {'base': 8, 'quote': 8, 'amount': 0, 'price': 4}
# limits          {'amount': {'min': 1.0, 'max': 92141578.0}, 'p...
# id                                                        FETBUSD
# lowercaseId                                               fetbusd
# symbol                                                   FET/BUSD
# base                                                          FET
# quote                                                        BUSD
# baseId                                                        FET
# quoteId                                                      BUSD
# info            {'symbol': 'FETBUSD', 'status': 'TRADING', 'ba...
# spot                                                         True
# type                                                         spot
# margin                                                      False
# future                                                      False
# delivery                                                    False
# linear                                                      False
# inverse                                                     False
# expiry                                                       None
# expiryDatetime                                               None
# active                                                       True
# contractSize                                                 None
#
# [26 rows x 1658 columns]

# %%
exchange = ccxt.binance ({
    'rateLimit': 1000,  # unified exchange property
    'headers': {
        'YOUR_CUSTOM_HTTP_HEADER': 'YOUR_CUSTOM_VALUE',
    },
    'options': {
        'adjustForTimeDifference': True,  # exchange-specific option
    }
})
exchange.options['adjustForTimeDifference'] = False
